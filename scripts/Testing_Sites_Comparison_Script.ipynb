# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
testing = pd.read_csv("/content/drive/MyDrive/pfas_python_files/preprocessing/testing_sites.csv", encoding = 'unicode_escape', engine ='python')
industries = pd.read_csv("/content/drive/MyDrive/pfas_python_files/preprocessing/industries.csv", encoding = 'unicode_escape', engine ='python')

uscities = pd.read_csv("/content/drive/MyDrive/pfas_python_files/preprocessing/25_Final_Dataframe.csv", encoding = 'unicode_escape', engine ='python')

industries = industries[(industries['Latitude'] != '-') & (industries['Longitude'] != '-')]
industries['Latitude'] = pd.to_numeric(industries['Latitude'], errors='coerce')
industries['Longitude'] = pd.to_numeric(industries['Longitude'], errors='coerce')
industries = industries[['Latitude', 'Longitude']]

# %% [markdown]
# # LAMBDA FUNCTIONS TO CALCULATE HAVERSINE DISTANCES AND TAKE AVERAGE

# %%
import pandas as pd
from math import radians, sin, cos, sqrt, atan2

i = 0
j = 0
# Haversine formula as a lambda function with distance in miles and print statements
def haversine_distance_miles(lat1, lon1, lat2, lon2):
    global i
    global j
    lat1_rad, lon1_rad, lat2_rad, lon2_rad = map(radians, [lat1, lon1, lat2, lon2])
    radius = 3958.8
    d_lat = lat2_rad - lat1_rad
    d_lon = lon2_rad - lon1_rad
    a = sin(d_lat / 2)**2 + cos(lat1_rad) * cos(lat2_rad) * sin(d_lon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = radius * c
    print("i: " + str(i) + "   //  j: " + str(j) + "           out of " + str(len(testing)))
    i = i + 1
    return distance

def haversine_loop(row1):
    global j
    global i
    testing.apply(lambda row2: (haversine_distance_miles(row1['latitude'], row1['longitude'], row2['latitude'], row2['longitude'])), axis=1)
    j = j + 1
    i = 0


# Calculate distances between all pairs of points using lambda function and apply method
distances = testing.apply(lambda row1: haversine_loop(row1), axis=1)

# Flatten the distances list of lists into a single list
all_testing_site_distances = [distance for sublist in distances for _, _, _, _, distance in sublist]

# Calculate the average distance
average_testing_site_distance = sum(all_testing_site_distances) / len(all_testing_site_distances)

print("Average distance between Latitude/Longitude points for testing sites:", average_distance, "miles")
# Out:
# Streaming output truncated to the last 5000 lines.
# i: 692   //  j: 230           out of 2332
# i: 693   //  j: 230           out of 2332
# i: 694   //  j: 230           out of 2332
# i: 695   //  j: 230           out of 2332
# i: 696   //  j: 230           out of 2332
# i: 697   //  j: 230           out of 2332
# i: 698   //  j: 230           out of 2332
# i: 699   //  j: 230           out of 2332
# i: 700   //  j: 230           out of 2332
# i: 701   //  j: 230           out of 2332
# i: 702   //  j: 230           out of 2332
# i: 703   //  j: 230           out of 2332
# i: 704   //  j: 230           out of 2332
# i: 705   //  j: 230           out of 2332
# i: 706   //  j: 230           out of 2332
# i: 707   //  j: 230           out of 2332
# i: 708   //  j: 230           out of 2332
# i: 709   //  j: 230           out of 2332
# i: 710   //  j: 230           out of 2332
# i: 711   //  j: 230           out of 2332
# i: 712   //  j: 230           out of 2332
# ...

# %%
import pandas as pd
from math import radians, sin, cos, sqrt, atan2

i = 0
j = 0
# Haversine formula as a lambda function with distance in miles and print statements
def haversine_distance_miles(lat1, lon1, lat2, lon2):
    global i
    global j
    lat1_rad, lon1_rad, lat2_rad, lon2_rad = map(radians, [lat1, lon1, lat2, lon2])
    radius = 3958.8
    d_lat = lat2_rad - lat1_rad
    d_lon = lon2_rad - lon1_rad
    a = sin(d_lat / 2)**2 + cos(lat1_rad) * cos(lat2_rad) * sin(d_lon / 2)**2
    c = 2 * atan2(sqrt(a), sqrt(1 - a))
    distance = radius * c
    print("i: " + str(i) + "  //  j: " + str(j) + "          out of " + str(len(industries)))
    i = i + 1
    return distance

def haversine_loop(row1):
    global j
    global i
    industries.apply(lambda row2: (haversine_distance_miles(row1['Latitude'], row1['Longitude'], row2['Latitude'], row2['Longitude'])), axis=1)
    j = j + 1
    i = 0

# Calculate distances between all pairs of points using lambda function and apply method
distances = industries.apply(lambda row1: haversine_loop(row1), axis=1)

# Flatten the distances list of lists into a single list
all_industry_site_distances = [distance for sublist in distances for _, _, _, _, distance in sublist]

# Calculate the average distance
average_industry_site_distance = sum(all_industry_site_distances) / len(all_industry_site_distances)

print("Average distance between Latitude/Longitude points for testing sites:", average_industry_site_distance, "miles")
# Out:
# Streaming output truncated to the last 5000 lines.
# 11778
# 11779
# 11780
# 11781
# 11782
# 11783
# 11784
# 11785
# 11786
# 11787
# 11788
# 11789
# 11790
# 11791
# 11792
# 11793
# 11794
# 11795
# 11796
# 11797
# 11798
# 11799
# 11800
# 11801
# 11802
# 11803
# 11804
# 11805
# 11806
# 11807
# 11808
# 11809
# 11810
# 11811
# 11812
# 11813
# 11814
# 11815
# 11816
# 11817
# 11818
# 11819
# 11820
# 11821
# 11822
# 11823
# 11824
# 11825
# 11826
# 11827
# 11828
# 11829
# 11830
# 11831
# 11832
# 11833
# 11834
# 11835
# 11836
# 11837
# 11838
# 11839
# 11840
# 11841
# 11842
# 11843
# 11844
# 11845
# 11846
# 11847
# 11848
# 11849
# 11850
# 11851
# 11852
# 11853
# 11854
# 11855
# 11856
# 11857
# 11858
# 11859
# 11860
# 11861
# 11862
# 11863
# 11864
# 11865
# 11866
# 11867
# 11868
# 11869
# 11870
# 11871
# 11872
# 11873
# 11874
# 11875
# 11876
# 11877
# 11878
# 11879
# 11880
# 11881
# 11882
# 11883
# 11884
# 11885
# 11886
# 11887
# 11888
# 11889
# 11890
# 11891
# 11892
# 11893
# 11894
# 11895
# ...
